# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv(r"C:\Users\gsksd\Downloads\placement.csv")
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.drop('Unnamed: 0' , axis = 1 , inplace = True , errors = 'ignore')
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(
    x = df['cgpa'] ,
    y = df['iq'] ,
    hue = df['placement']
) 
plt.show()

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %% [markdown]
# train test split

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train , X_test , y_train , y_test
# Out:
# (    cgpa     iq
#  89   4.9  151.0
#  56   6.1   65.0
#  48   6.6  138.0
#  37   8.1  149.0
#  27   6.0  124.0
#  ..   ...    ...
#  38   6.5  160.0
#  59   4.8  112.0
#  53   8.3  168.0
#  88   4.4  149.0
#  54   6.4  141.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  96   4.4   42.0
#  66   6.9   96.0
#  86   5.1  128.0
#  9    5.1   66.0
#  23   4.7   87.0
#  20   6.6  120.0
#  94   4.7   52.0
#  80   4.9  196.0
#  21   7.1  151.0
#  61   7.3  137.0,
#  89    0
#  56    0
#  48    1
#  37    1
#  27    1
#       ..
#  38    1
#  59    0
#  53    1
#  88    0
#  54    1
#  Name: placement, Length: 90, dtype: int64,
#  96    0
#  66    1
#  86    0
#  9     0
#  23    0
#  20    1
#  94    0
#  80    0
#  21    1
#  61    1
#  Name: placement, dtype: int64)

# %% [markdown]
# scaling the values

# %%
scalar = StandardScaler()
X_train = scalar.fit_transform(X_train)
X_train
# Out:
# array([[-0.98890657,  0.66364928],
#        [ 0.06540646, -1.56289836],
#        [ 0.50470355,  0.32707812],
#        [ 1.82259484,  0.6118691 ],
#        [-0.02245296, -0.03538312],
#        [-0.02245296, -1.53700827],
#        [ 1.82259484,  1.05200061],
#        [ 1.29543832,  0.11995741],
#        [ 0.24112529,  0.06817723],
#        [-0.72532831,  0.92255016],
#        [-0.02245296, -0.60496507],
#        [ 0.68042239, -0.91564614],
#        [-0.02245296,  0.6118691 ],
#        [-1.77964134, -1.30399747],
#        [ 1.29543832,  0.8448799 ],
#        [ 0.06540646, -1.14865694],
#        [ 0.85614123,  0.35296821],
#        [ 0.24112529,  0.04228714],
#        [-2.39465728,  1.49213212],
#        [ 0.59256297,  1.46624203],
#        [-1.16462541, -0.11305339],
#        [-1.51606309,  1.93226362],
#        [ 1.73473542, -1.20043712],
#        [-0.98890657,  0.76720963],
#        [-0.90104715, -1.61467854],
#        [-0.98890657, -1.66645871],
#        [-0.6374689 , -0.29428401],
#        [ 0.06540646,  0.79309972],
#        [-1.86750076, -0.42373445],
#        [ 0.68042239,  0.40474839],
#        [ 1.55901658, -0.29428401],
#        [-0.28603122,  0.45652857],
#        [ 1.38329774,  0.06817723],
#        [-0.1981718 ,  0.43063848],
#        [ 1.38329774, -0.94153623],
#        [-1.77964134, -0.65674525],
#        [-1.07676599,  0.97433034],
#        [ 1.11971948, -1.01920649],
#        [ 0.41684413, -2.28782084],
#        [-0.98890657, -0.13894348],
#        [ 1.29543832, -1.66645871],
#        [-0.28603122,  0.3788583 ],
#        [ 0.24112529, -0.57907499],
#        [ 0.32898471, -0.24250383],
#        [ 0.06540646, -0.57907499],
#        [ 0.41684413,  0.11995741],
#        [-1.07676599,  1.12967087],
#        [ 0.59256297,  0.74131954],
#        [ 1.11971948, -0.24250383],
#        [ 1.2075789 ,  0.17173759],
#        [-2.21893844,  2.78663655],
#        [ 0.15326588, -0.3201741 ],
#        [ 0.41684413, -0.91564614],
#        [ 1.11971948, -1.95124969],
#        [-0.72532831,  2.55362575],
#        [-0.90104715, -0.19072365],
#        [ 0.85614123, -1.58878845],
#        [-0.98890657,  0.22351777],
#        [-0.28603122,  1.12967087],
#        [ 0.68042239, -0.06127321],
#        [-0.1981718 ,  1.05200061],
#        [-0.90104715, -0.88975605],
#        [ 0.85614123,  1.28501141],
#        [ 2.17403251, -0.13894348],
#        [-0.28603122,  0.17173759],
#        [-0.81318773,  1.31090149],
#        [-0.54960948,  0.35296821],
#        [ 0.85614123, -0.34606419],
#        [ 0.06540646,  0.17173759],
#        [-0.11031238, -0.50140472],
#        [-0.72532831,  0.17173759],
#        [ 0.76828181,  0.35296821],
#        [-0.72532831, -0.39784436],
#        [-0.54960948, -0.47551463],
#        [-1.07676599,  0.40474839],
#        [-1.25248483,  0.53419883],
#        [ 0.68042239, -0.34606419],
#        [-0.54960948, -0.29428401],
#        [-0.72532831, -0.91564614],
#        [-0.6374689 , -0.11305339],
#        [ 0.76828181,  0.32707812],
#        [-0.54960948,  0.24940785],
#        [ 0.94400065, -2.00302987],
#        [ 0.85614123,  1.90637354],
#        [-0.02245296, -2.08070013],
#        [ 0.41684413,  0.89666007],
#        [-1.07676599, -0.34606419],
#        [ 1.99831368,  1.10378078],
#        [-1.42820367,  0.6118691 ],
#        [ 0.32898471,  0.40474839]])

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

X_test = scalar.transform(X_test)

# %% [markdown]
# model training

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([0, 1, 0, 0, 0, 1, 0, 0, 1, 1])

# %%
y_test
# Out:
# 96    0
# 66    1
# 86    0
# 9     0
# 23    0
# 20    1
# 94    0
# 80    0
# 21    1
# 61    1
# Name: placement, dtype: int64

# %%
accuracy_score(y_test ,  y_pred)
# Out:
# 1.0

# %%
plot_decision_regions(X_train , y_train.values , clf=clf ,legend=2)
# Out:
# <Axes: >

# %%
with open('toydata.pkl', 'wb') as file:
    pickle.dump(clf, file)
