# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %% [markdown]
# # Loading the data set

# %%
df = pd.read_csv(r"C:\Users\gsksd\Downloads\Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Asking questions to the data set

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 817          818         0       2
# 425          426         0       3
# 41            42         0       2
# 574          575         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 817                                 Mallet, Mr. Albert    male  31.0      1
# 425                             Wiseman, Mr. Phillippe    male   NaN      0
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 574                       Rush, Mr. Alfred George John    male  16.0      0
#
#      Parch           Ticket      Fare        Cabin Embarked
# 27       2            19950  263.0000  C23 C25 C27        S
# 817      1  S.C./PARIS 2079   37.0042          NaN        C
# 425      0       A/4. 34244    7.2500          NaN        S
# ...

# %% [markdown]
# # Data type of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Finding missing values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # How does data looks mathematically

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Duplicated values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Corellation b/w numbers

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# # Univarate Analysis

# %% [markdown]
# ## Categorical data

# %% [markdown]
# ### a) Countplot

# %% [markdown]
# #### count plot for Survived feature

# %%
sns.countplot(x =df['Survived'])
df['Survived'].value_counts() 
plt.show()
df['Survived'].value_counts().plot(kind = 'pie' , autopct = '%.2f')
plt.show()

# %% [markdown]
# #### count plot for Pclass feature

# %%
sns.countplot(x =df['Pclass'])
df['Pclass'].value_counts()
plt.show()
df['Pclass'].value_counts().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### countplot for sex

# %%
sns.countplot(x =df['Sex'])
df['Sex'].value_counts()
plt.show()
df['Sex'].value_counts().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### countplot for Embarked

# %%
sns.countplot(x =df['Embarked'])
df['Embarked'].value_counts()
plt.show()
df['Embarked'].value_counts().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x =df['Parch'])
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %% [markdown]
# ## Numerical values

# %% [markdown]
# ### histplot & KDE plot for Age

# %%
sns.histplot(x =df['Age'])
df['Age'].value_counts()
plt.show()
sns.kdeplot(x =df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### boxplot for fare

# %%
sns.boxplot(x =df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %% [markdown]
# # Bivarate Analysis & Multivarate Analysis

# %% [markdown]
# ## Scatter plot (Numerical to Numerical)

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip')
plt.show()

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip' , hue = 'sex' , style = 'smoker' , size = 'size')
plt.show()

# %% [markdown]
# ## Boxplot for (Numerical to Categorical)

# %%
sns.barplot(x = df['Pclass'] , y = df['Age'] ) 
plt.show()

# %%
sns.barplot(x = df['Pclass'] , y = df['Age'] , hue = df['Sex'] ) 
plt.show()

# %% [markdown]
# ### box plot for (Numerical to Categorical))

# %%
sns.boxplot(x = df['Sex'] , y = df['Age'])
plt.show()

# %%
sns.boxplot(x = df['Pclass'] , y = df['Age'] , hue = df['Sex'] ) 
plt.show()

# %% [markdown]
# ## Distplot AKA KDE plot (Numerical to Categorical)

# %%
sns.histplot(data=df, x='Age', hue='Survived', kde=True)
plt.show()

# %% [markdown]
# # Heat map for (Categorical - Categorical)

# %%
pd.crosstab(df['Pclass'] , df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df['Pclass'] , df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# ## clustermap for (Categorical - Categorical)

# %%
pd.crosstab(df['SibSp'] , df['Survived'])
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
sns.clustermap(pd.crosstab(df['SibSp'] , df['Survived']))

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(df, hue='Sex')
plt.show()

# %% [markdown]
# ## Lineplot for (Numerical to Numerical)

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
new = flights.groupby('year').sum(numeric_only=True)

# %%
sns.lineplot(data=new, x='year', y='passengers')
plt.show()

# %% [markdown]
# ## pivot table

# %%
flights.pivot_table(
    values = 'passengers', 
    index = 'month',
    columns = 'year'
)
# Out:
# C:\Users\gsksd\AppData\Local\Temp\ipykernel_26880\988289467.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
sns.heatmap(flights.pivot_table(
    values = 'passengers', 
    index = 'month',
    columns = 'year'
))
# Out:
# C:\Users\gsksd\AppData\Local\Temp\ipykernel_26880\321137171.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(
    values = 'passengers', 
    index = 'month',
    columns = 'year'
))
plt.show()
# Out:
# C:\Users\gsksd\AppData\Local\Temp\ipykernel_26880\3102728595.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(
