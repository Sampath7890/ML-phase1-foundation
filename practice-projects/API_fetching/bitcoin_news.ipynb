# %%
import pandas as pd
import requests

# %%
response = requests.get("https://newsapi.org/v2/everything?q=bitcoin&apiKey=ed8dc92685864caba98da594a84bddff")

# %%
df = pd.DataFrame(response.json()["articles"])
df
# Out:
#                                       source  \
# 0   {'id': 'the-verge', 'name': 'The Verge'}
# 1        {'id': None, 'name': 'Gizmodo.com'}
# 2        {'id': None, 'name': 'Gizmodo.com'}
# 3        {'id': None, 'name': 'Gizmodo.com'}
# 4        {'id': None, 'name': 'Gizmodo.com'}
# ..                                       ...
# 92          {'id': None, 'name': 'CoinDesk'}
# 93          {'id': None, 'name': 'CoinDesk'}
# 94          {'id': None, 'name': 'CoinDesk'}
# 95       {'id': None, 'name': 'Gizmodo.com'}
# 96            {'id': None, 'name': 'Forbes'}
#
#                                                author  \
# 0                                         Robert Hart
# 1                                         Kyle Torpey
# 2                                         Kyle Torpey
# 3                                         Kyle Torpey
# 4                                         Rhett Jones
# ..                                                ...
# ...

# %%
df[["source_id" , "source_name"]] = df["source"].apply(pd.Series)
df
# Out:
#                                       source  \
# 0   {'id': 'the-verge', 'name': 'The Verge'}
# 1        {'id': None, 'name': 'Gizmodo.com'}
# 2        {'id': None, 'name': 'Gizmodo.com'}
# 3        {'id': None, 'name': 'Gizmodo.com'}
# 4        {'id': None, 'name': 'Gizmodo.com'}
# ..                                       ...
# 92          {'id': None, 'name': 'CoinDesk'}
# 93          {'id': None, 'name': 'CoinDesk'}
# 94          {'id': None, 'name': 'CoinDesk'}
# 95       {'id': None, 'name': 'Gizmodo.com'}
# 96            {'id': None, 'name': 'Forbes'}
#
#                                                author  \
# 0                                         Robert Hart
# 1                                         Kyle Torpey
# 2                                         Kyle Torpey
# 3                                         Kyle Torpey
# 4                                         Rhett Jones
# ..                                                ...
# ...

# %%
df.drop(columns=['source'], inplace=True)

df.head()
# Out:
#         author                                              title  \
# 0  Robert Hart  I went looking for the AI weed vape that gives...
# 1  Kyle Torpey  Why Would Someone Publicly Burn $8 Million Wor...
# 2  Kyle Torpey  The Word of God Now Comes With Bitcoin Rewards...
# 3  Kyle Torpey  Largest US Banks to Launch Tokenization Networ...
# 4  Rhett Jones  Crypto Promoters Say Blockchain Is the Future ...
#
#                                          description  \
# 0  The crypto weed vape found me on 4/20, the hig...
# 1     And another question: How do you burn bitcoin?
# 2               In 2026, even the Bible is gamified.
# 3  The traditional banking industry has a long hi...
# 4  Is crypto really the secret sauce that AI is m...
#
#                                                  url  \
# 0  https://www.theverge.com/ai-artificial-intelli...
# 1  https://gizmodo.com/why-would-someone-publicly...
# 2  https://gizmodo.com/the-word-of-god-now-comes-...
# ...

# %%
df.shape
# Out:
# (97, 9)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                author  \
# 0                                         Robert Hart
# 1                                         Kyle Torpey
# 2                                         Kyle Torpey
# 3                                         Kyle Torpey
# 4                                         Rhett Jones
# ..                                                ...
# 92                                      Shaurya Malwa
# 93                                      Olivier Acuna
# 94                                      Shaurya Malwa
# 95                            Martín Nicolás Parolari
# 96  Ty Roush, Forbes Staff, \n Ty Roush, Forbes St...
#
#                                                 title  \
# 0   I went looking for the AI weed vape that gives...
# 1   Why Would Someone Publicly Burn $8 Million Wor...
# 2   The Word of God Now Comes With Bitcoin Rewards...
# 3   Largest US Banks to Launch Tokenization Networ...
# ...

# %%
df.isnull().sum()
# Out:
# author          6
# title           0
# description     4
# url             0
# urlToImage      7
# publishedAt     0
# content         0
# source_id      85
# source_name     0
# dtype: int64

# %%
df.to_csv()
