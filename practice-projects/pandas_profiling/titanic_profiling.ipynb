# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\gsksd\Downloads\Titanic-Dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
conda install matplotlib=3.11.0
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\gsksd\anaconda3
#
#   added / updated specs:
#     - matplotlib=3.11.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.5.14  |       haa95532_0         107 KB
#     certifi-2026.6.17          |  py313haa95532_0         131 KB
#     conda-26.1.1               |  py313haa95532_0         1.2 MB
#     freetype-2.14.1            |       hfbffc0b_0         514 KB
#     libpng-1.6.56              |       h2854ad3_0         239 KB
#     matplotlib-3.11.0          |  py313haa95532_0           7 KB
#     matplotlib-base-3.11.0     |  py313h330ff07_0         8.2 MB
#     openssl-3.5.7              |       hbb43b14_0         8.9 MB
#     ------------------------------------------------------------
#                                            Total:        19.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.11.0-py313h330ff07_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.11.4-haa95532_0 --> 2026.5.14-haa95532_0
#   certifi                        2025.11.12-py313haa95532_0 --> 2026.6.17-py313haa95532_0
#   conda                             25.11.1-py313haa95532_0 --> 26.1.1-py313haa95532_0
#   freetype                                2.13.3-h0620614_0 --> 2.14.1-hfbffc0b_0
#   libpng                                  1.6.50-h46444df_0 --> 1.6.56-h2854ad3_0
#   matplotlib                         3.10.6-py313haa95532_1 --> 3.11.0-py313haa95532_0
#   openssl                                 3.0.18-h543e019_0 --> 3.5.7-hbb43b14_0
#
#
#
# Downloading and Extracting Packages: ...working...
# openssl-3.5.7        | 8.9 MB    |            |   0%
#
# matplotlib-base-3.11 | 8.2 MB    |            |   0%
#
#
# conda-26.1.1         | 1.2 MB    |            |   0%
#
#
#
# freetype-2.14.1      | 514 KB    |            |   0%
#
#
#
#
# libpng-1.6.56        | 239 KB    |            |   0%
#
#
#
#
#
# certifi-2026.6.17    | 131 KB    |            |   0%
#
#
#
#
#
#
# ca-certificates-2026 | 107 KB    |            |   0%
#
#
#
#
#
#
#
# matplotlib-3.11.0    | 7 KB      |            |   0%
#
#
# conda-26.1.1         | 1.2 MB    | 1          |   1%
#
#
#
#
# libpng-1.6.56        | 239 KB    | 6          |   7%
# openssl-3.5.7        | 8.9 MB    |            |   0%
#
#
#
# freetype-2.14.1      | 514 KB    | 3          |   3%
#
# matplotlib-base-3.11 | 8.2 MB    |            |   0%
#
#
#
#
# libpng-1.6.56        | 239 KB    | ########## | 100%
#
#
# conda-26.1.1         | 1.2 MB    | ###3       |  33%
#
#
#
# freetype-2.14.1      | 514 KB    | #####5     |  56%
# openssl-3.5.7        | 8.9 MB    | 2          |   3%
#
# matplotlib-base-3.11 | 8.2 MB    | 2          |   3%
#
#
#
# freetype-2.14.1      | 514 KB    | ########## | 100%
#
#
#
#
# libpng-1.6.56        | 239 KB    | ########## | 100%
#
#
#
#
# libpng-1.6.56        | 239 KB    | ########## | 100%
#
#
#
#
#
# certifi-2026.6.17    | 131 KB    | #2         |  12%
#
#
#
#
#
# certifi-2026.6.17    | 131 KB    | ########## | 100%
#
#
#
#
#
#
# ca-certificates-2026 | 107 KB    | #4         |  15%
#
#
#
#
#
#
# ca-certificates-2026 | 107 KB    | ########## | 100%
#
#
# conda-26.1.1         | 1.2 MB    | #######8   |  78%
#
#
#
#
#
#
#
# matplotlib-3.11.0    | 7 KB      | ########## | 100%
# openssl-3.5.7        | 8.9 MB    | 7          |   8%
#
# matplotlib-base-3.11 | 8.2 MB    | 7          |   7%
#
#
#
#
#
#
#
# matplotlib-3.11.0    | 7 KB      | ########## | 100%
#
#
#
#
#
# certifi-2026.6.17    | 131 KB    | ########## | 100%
#
#
# conda-26.1.1         | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
# ca-certificates-2026 | 107 KB    | ########## | 100%
#
#
#
#
#
#
#
# matplotlib-3.11.0    | 7 KB      | ########## | 100%
#
#
#
# freetype-2.14.1      | 514 KB    | ########## | 100%
#
#
#
# freetype-2.14.1      | 514 KB    | ########## | 100%
# openssl-3.5.7        | 8.9 MB    | #9         |  20%
#
# matplotlib-base-3.11 | 8.2 MB    | #6         |  17%
# openssl-3.5.7        | 8.9 MB    | ##7        |  27%
#
# matplotlib-base-3.11 | 8.2 MB    | ##7        |  27%
#
# matplotlib-base-3.11 | 8.2 MB    | ###6       |  36%
# openssl-3.5.7        | 8.9 MB    | ###6       |  36%
#
# matplotlib-base-3.11 | 8.2 MB    | ####8      |  48%
# openssl-3.5.7        | 8.9 MB    | ####5      |  45%
# openssl-3.5.7        | 8.9 MB    | #####7     |  57%
#
# matplotlib-base-3.11 | 8.2 MB    | ######     |  60%
#
#
# conda-26.1.1         | 1.2 MB    | ########## | 100%
#
# matplotlib-base-3.11 | 8.2 MB    | #######2   |  73%
# openssl-3.5.7        | 8.9 MB    | ######5    |  66%
#
# matplotlib-base-3.11 | 8.2 MB    | ########5  |  85%
# openssl-3.5.7        | 8.9 MB    | #######9   |  80%
#
# matplotlib-base-3.11 | 8.2 MB    | ########## | 100%
#
# matplotlib-base-3.11 | 8.2 MB    | ########## | 100%
# openssl-3.5.7        | 8.9 MB    | ########8  |  89%
# openssl-3.5.7        | 8.9 MB    | #########7 |  97%
# openssl-3.5.7        | 8.9 MB    | ########## | 100%
# openssl-3.5.7        | 8.9 MB    | ########## | 100%
#
# matplotlib-base-3.11 | 8.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Channel "defaults" has the following notices:
#   [info] -- Tue Jun  9 00:00:00 2026
#   PyTorch 2.12 with CUDA support is now available to install with your current channel (Anaconda Main). Learn more: https://anaconda.org/main/pytorch?utm_source=channel_notices
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.11.0

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, explorative=True)
profile.to_file("titanic_profiling.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 128.51it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
